# %%
#import sys
#!{sys.executable} -m pip install git+https://github.com/saezlab/pypath.git
# Out:
# Collecting git+https://github.com/saezlab/pypath.git
#   Cloning https://github.com/saezlab/pypath.git to /tmp/pip-req-build-wwzeowsg
#   Running command git clone --filter=blob:none --quiet https://github.com/saezlab/pypath.git /tmp/pip-req-build-wwzeowsg
#   Resolved https://github.com/saezlab/pypath.git to commit c98ce67f191dfef6dcb2926916a7fc491a677cb9
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: PyYAML in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (4.12.3)
# Requirement already satisfied: certifi>=2023.7.22 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (2024.2.2)
# Collecting cryptography>=41.0.4
#   Downloading cryptography-42.0.7-cp39-abi3-manylinux_2_28_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 19.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: dill in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (0.3.8)
# Collecting future
#   Downloading future-1.0.0-py3-none-any.whl (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 22.6 MB/s eta 0:00:00
# Collecting glom
#   Downloading glom-23.5.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 11.1 MB/s eta 0:00:00
# Collecting lxml
#   Downloading lxml-5.2.2-cp311-cp311-manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 36.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (3.8.3)
# Requirement already satisfied: numpy in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (1.26.4)
# Requirement already satisfied: openpyxl in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (3.1.2)
# Requirement already satisfied: pandas in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (2.2.1)
# Requirement already satisfied: psutil in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (5.9.8)
# Collecting pycurl
#   Downloading pycurl-7.45.3-cp311-cp311-manylinux_2_28_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 45.5 MB/s eta 0:00:00:00:0100:01
# Collecting pypath-common>=0.2.0
#   Downloading pypath_common-0.2.2-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 6.3 MB/s eta 0:00:00
# Collecting pyreadr
#   Downloading pyreadr-0.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.0/440.0 kB 15.1 MB/s eta 0:00:00
# Collecting pysftp<0.3.0,>=0.2.9
#   Using cached pysftp-0.2.9-py3-none-any.whl
# Collecting rdata
#   Downloading rdata-0.11.2-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (2.31.0)
# Requirement already satisfied: scipy>=1.9.0 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (1.11.4)
# Collecting sqlparse
#   Downloading sqlparse-0.5.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.1 MB/s eta 0:00:00
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting timeloop
#   Using cached timeloop-1.0.2-py3-none-any.whl
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tornado>=3.6.6 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (6.4)
# Requirement already satisfied: tqdm in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (4.66.2)
# Requirement already satisfied: typing_extensions in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (4.10.0)
# Requirement already satisfied: xlrd in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-omnipath==0.16.15) (2.0.1)
# Requirement already satisfied: cffi>=1.12 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from cryptography>=41.0.4->pypath-omnipath==0.16.15) (1.16.0)
# Requirement already satisfied: platformdirs in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pypath-common>=0.2.0->pypath-omnipath==0.16.15) (4.2.0)
# Collecting paramiko>=1.17
#   Downloading paramiko-3.4.0-py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.9/225.9 kB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from beautifulsoup4->pypath-omnipath==0.16.15) (2.5)
# Collecting boltons>=19.3.0
#   Downloading boltons-24.0.0-py3-none-any.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.7/191.7 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from glom->pypath-omnipath==0.16.15) (23.2.0)
# Collecting face==20.1.1
#   Downloading face-20.1.1-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from matplotlib->pypath-omnipath==0.16.15) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from matplotlib->pypath-omnipath==0.16.15) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from matplotlib->pypath-omnipath==0.16.15) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from matplotlib->pypath-omnipath==0.16.15) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from matplotlib->pypath-omnipath==0.16.15) (24.0)
# Requirement already satisfied: pillow>=8 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from matplotlib->pypath-omnipath==0.16.15) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from matplotlib->pypath-omnipath==0.16.15) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from matplotlib->pypath-omnipath==0.16.15) (2.9.0.post0)
# Requirement already satisfied: et-xmlfile in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from openpyxl->pypath-omnipath==0.16.15) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pandas->pypath-omnipath==0.16.15) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from pandas->pypath-omnipath==0.16.15) (2024.1)
# Collecting xarray
#   Downloading xarray-2024.5.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from requests->pypath-omnipath==0.16.15) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from requests->pypath-omnipath==0.16.15) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from requests->pypath-omnipath==0.16.15) (2.2.1)
# Requirement already satisfied: pycparser in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=41.0.4->pypath-omnipath==0.16.15) (2.21)
# Collecting bcrypt>=3.2
#   Downloading bcrypt-4.1.3-cp39-abi3-manylinux_2_28_x86_64.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 25.8 MB/s eta 0:00:00
# Collecting pynacl>=1.5
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 37.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /home/people/lerlmeier/Apps/pyenv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->pypath-omnipath==0.16.15) (1.16.0)
# Building wheels for collected packages: pypath-omnipath
#   Building wheel for pypath-omnipath (pyproject.toml) ... done
#   Created wheel for pypath-omnipath: filename=pypath_omnipath-0.16.15-py3-none-any.whl size=1134971 sha256=05aab89b01665801330bd8aa83e2660e29c8171106d0c0484acee1b3ccc43d82
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kfio9cd9/wheels/b3/3b/d6/58404ca9902958efa862328ce8196a0b48435c04fb35b33f85
# Successfully built pypath-omnipath
# Installing collected packages: timeloop, toml, tabulate, sqlparse, pycurl, lxml, future, boltons, bcrypt, pypath-common, pynacl, face, cryptography, xarray, pyreadr, paramiko, glom, rdata, pysftp, pypath-omnipath
# Successfully installed bcrypt-4.1.3 boltons-24.0.0 cryptography-42.0.7 face-20.1.1 future-1.0.0 glom-23.5.0 lxml-5.2.2 paramiko-3.4.0 pycurl-7.45.3 pynacl-1.5.0 pypath-common-0.2.2 pypath-omnipath-0.16.15 pyreadr-0.5.0 pysftp-0.2.9 rdata-0.11.2 sqlparse-0.5.0 tabulate-0.9.0 timeloop-1.0.2 toml-0.10.2 xarray-2024.5.0

# %%
import sys
import logging

nblog = open("nb.log", "a+")
sys.stdout.echo = nblog
sys.stderr.echo = nblog

get_ipython().log.handlers[0].stream = nblog
get_ipython().log.setLevel(logging.INFO)

# %%
import pandas as pd
import scanpy as sc
import plotnine as p9

import liana as li
import cell2cell as c2c
import decoupler as dc # needed for pathway enrichment

import warnings
warnings.filterwarnings('ignore')
from collections import defaultdict

# %matplotlib inline

# %%
adata = sc.read_h5ad(filename='../data/3_full_anndata.h5ad')

# %%
sample_key = 'sample_treat'
condition_key = 'treatment.agg'
groupby = 'celltype'

# %%
sc.pl.umap(adata, color=[condition_key, groupby], frameon=False)

# %%
samples_used = adata.obs[adata.obs[sample_key].map(adata.obs[sample_key].value_counts()) > 2][sample_key].cat.remove_unused_categories().unique()

# %%
#Removed 3 cells that were in isolated sample_treat combinations. These cells made the further 
#analysis fail. 
adata = adata[adata.obs[sample_key].isin(samples_used)].copy()

# %%
li.mt.rank_aggregate.by_sample(
    adata,
    groupby=groupby,
    min_cells=0,
    sample_key=sample_key, # sample key by which we which to loop
    use_raw=False,
    resource_name='mouseconsensus',
    verbose=True, # use 'full' to show all verbose information
    n_perms=200, # reduce permutations for speed
    return_all_lrs=True, # return all LR values
    )
# Out:
# Now running: fLN_40B2___HDAC_cKO:   1%|          | 1/84 [01:35<2:11:32, 95.09s/it]

# %%
adata.uns["liana_res"] = pd.concat(adata.uns["liana_res"].values(), keys = adata.uns["liana_res"].keys())
adata.uns["liana_res"] = adata.uns["liana_res"].reset_index(level=0).rename({'level_0':'sample_treat'}, axis=1)

# %%
#adata=sc.read_h5ad('../../../../vscratch/scRNAseq/data/8_adata_pre_tensor_huge.h5ad')

# %%
# ?li.multi.to_tensor_c2c

# %%
tensor = li.multi.to_tensor_c2c(adata,
                                sample_key=sample_key,
                                score_key='magnitude_rank', # can be any score from liana
                                how='outer_cells' # how to join the samples
                                )
# Out:
# 100%|██████████| 84/84 [00:51<00:00,  1.63it/s]

# %%
c2c.io.export_variable_with_pickle(tensor, "../data/tensor_liana.pkl")
# Out:
# ../data/tensor_liana.pkl  was correctly saved.

# %%
context_dict = adata.obs[[sample_key, condition_key]].drop_duplicates()
context_dict = dict(zip(context_dict[sample_key], context_dict[condition_key]))
context_dict = defaultdict(lambda: 'Unknown', context_dict)

tensor_meta = c2c.tensor.generate_tensor_metadata(interaction_tensor=tensor,
                                                  metadata_dicts=[context_dict, None, None, None],
                                                  fill_with_order_elements=True
                                                  )

# %%
tensor = c2c.analysis.run_tensor_cell2cell_pipeline(tensor,
                                                    tensor_meta,
                                                    copy_tensor=True, # Whether to output a new tensor or modifying the original
                                                    rank=None, # Number of factors to perform the factorization. If None, it is automatically determined by an elbow analysis. Here, it was precomuputed.
                                                    tf_optimization='regular', # To define how robust we want the analysis to be.
                                                    random_state=None, # Random seed for reproducibility
                                                    device='cpu', # Device to use. If using GPU and PyTorch, use 'cuda'. For CPU use 'cpu'
                                                    elbow_metric='error', # Metric to use in the elbow analysis.
                                                    smooth_elbow=False, # Whether smoothing the metric of the elbow analysis.
                                                    upper_rank=25, # Max number of factors to try in the elbow analysis
                                                    tf_init='random', # Initialization method of the tensor factorization
                                                    tf_svd='numpy_svd', # Type of SVD to use if the initialization is 'svd'
                                                    cmaps=None, # Color palettes to use in color each of the dimensions. Must be a list of palettes.
                                                    sample_col='Element', # Columns containing the elements in the tensor metadata
                                                    group_col='Category', # Columns containing the major groups in the tensor metadata
                                                    output_fig=False, # Whether to output the figures. If False, figures won't be saved a files if a folder was passed in output_folder.
                                                    )
# Out:
# Running Elbow Analysis
#  28%|██▊       | 7/25 [48:15<2:28:46, 495.93s/it]

# %%
factors, axes = c2c.plotting.tensor_factors_plot(interaction_tensor=tensor,
                                                 metadata = tensor_meta, # This is the metadata for each dimension
                                                 sample_col='Element',
                                                 group_col='Category',
                                                 meta_cmaps = ['viridis', 'Dark2_r', 'tab20', 'tab20'],
                                                 fontsize=10, # Font size of the figures generated
                                                 )

# %%
tensor.factors
# Out:
# OrderedDict([('Contexts',
#                                       Factor 1  Factor 2  Factor 3  Factor 4  Factor 5  \
#               fLN_40B2___HDAC_WT      0.111266  0.052210  0.225515  0.058648  0.063124
#               fLN_40B2___HDAC_cKO     0.129971  0.091926  0.134850  0.088587  0.188920
#               fLN_40B2___NoT          0.114749  0.141205  0.124113  0.076028  0.057941
#               fLN_40B2___Undefined    0.090170  0.061267  0.071987  0.083528  0.140602
#               fLN_41B1___HDAC_WT      0.076493  0.057741  0.138183  0.120979  0.165683
#               ...                          ...       ...       ...       ...       ...
#               mSkin_41B3___HDAC_cKO   0.162053  0.084783  0.049098  0.105852  0.014493
#               mSkin_41B3___NoT        0.093577  0.107897  0.005364  0.072735  0.040512
#               mSkin_41B3___Undefined  0.151937  0.140841  0.032175  0.149655  0.107988
#               mSkin_B1___HDAC_WT      0.079039  0.019052  0.062017  0.047277  0.045521
#               mSkin_B1___Undefined    0.052049  0.019329  0.009225  0.014489  0.027588
#
#                                       Factor 6  Condition
#               fLN_40B2___HDAC_WT      0.102983    HDAC_WT
#               fLN_40B2___HDAC_cKO     0.028350   HDAC_cKO
#               fLN_40B2___NoT          0.020421  Undefined
#               fLN_40B2___Undefined    0.021121        NoT
#               fLN_41B1___HDAC_WT      0.001994    HDAC_WT
#
#                                     Factor 6
#               Receiver Cells
#               B_follicular          0.132750
#               B_follicular_Fth_neg  0.077202
#               B_follicular_Mif+     0.001970
#               B_naive_mem           0.021579
#               DC                    0.173419
#               Endothelial_cells     0.117569
#               Fibroblasts_1         0.164505
#               Fibroblasts_2         0.217471
#               Fibroblasts_3         0.193366
#               Fibroblasts_4         0.074972
#               Fibroblasts_5         0.132552
#               Fibroblasts_6         0.022954
#               Keratinocytes_1       0.204412
#               Keratinocytes_10      0.069795
#               Keratinocytes_2       0.200200
#               Keratinocytes_3       0.210039
#               Keratinocytes_4       0.083733
#               Keratinocytes_5       0.212283
#               Keratinocytes_7       0.167878
#               Keratinocytes_8       0.173327
#               Keratinocytes_9       0.283976
#               Macrophages_1         0.196597
#               Macrophages_2         0.244326
#               Macrophages_3         0.096648
#               Melanocytes           0.160412
#               Monocytes             0.194360
#               Myofibroblasts        0.113613
#               Neutrophils           0.195334
#               Plasma_cells          0.011307
#               T_CD45.1_1            0.069680
#               T_CD45.1_2            0.106520
#               T_CD45.1_3            0.129482
#               T_cell_1              0.119526
#               T_cell_2              0.136072
#               T_gd_1                0.011259
#               T_gd_2                0.090449
#               T_gd_3                0.101794
#               T_gd_4                0.089176
#               T_gd_5                0.120423
#               Unassigned3           0.045065
#               Unassigned_B          0.082472
#               Undefined_M           0.175494
#               Undefined_T           0.153262
#               removed_B             0.238202
#               removed_T             0.160169  )])

# %%
factors = tensor.factors

# %%
factors.keys()
# Out:
# odict_keys(['Contexts', 'Ligand-Receptor Pairs', 'Sender Cells', 'Receiver Cells'])

# %%
_ = c2c.plotting.context_boxplot(context_loadings=factors['Contexts'],
                                 metadict=context_dict,
                                 nrows=2,
                                 figsize=(8, 6),
                                 statistical_test='t-test_ind',
                                 pval_correction='fdr_bh',
                                 cmap='plasma',
                                 verbose=True,
                                )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 _ = c2c.plotting.context_boxplot(context_loadings=factors['Contexts'],
#       2                                  metadict=context_dict,
#       3                                  nrows=2,
#       4                                  figsize=(8, 6),
#       5                                  statistical_test='t-test_ind',
#       6                                  pval_correction='fdr_bh',
#       7                                  cmap='plasma',
#       8                                  verbose=True,
#       9                                 )
#
# File ~/Apps/pyenv/lib/python3.11/site-packages/cell2cell/plotting/factor_plot.py:175, in context_boxplot(context_loadings, metadict, included_factors, group_order, statistical_test, pval_correction, text_format, nrows, figsize, cmap, title_size, axis_label_size, group_label_rotation, ylabel, dot_color, dot_edge_color, filename, verbose)
#     172 from itertools import combinations
#     174 pairs = list(combinations(order, 2))
# --> 175 annotator = Annotator(ax=ax,
#     176                       pairs=pairs,
#     177                       data=df,
#     178                       x=x,
#     179                       y=y,
#     180                       order=order)
#     181 annotator.configure(test=statistical_test,
#     182                     text_format=text_format,
#     183                     loc='inside',
#     184                     comparisons_correction=pval_correction,
#     185                     verbose=verbose
#     186                     )
#     187 annotator.apply_and_annotate()
#
# File ~/Apps/pyenv/lib/python3.11/site-packages/statannotations/Annotator.py:106, in Annotator.__init__(self, ax, pairs, plot, data, x, y, hue, order, hue_order, engine, verbose, **plot_params)
#     104     self._plotter = None
#     105 else:
# --> 106     self._plotter = self._get_plotter(engine, ax, pairs, plot, data,
#     107                                       x, y, hue, order, hue_order,
#     108                                       verbose=verbose, **plot_params)
#     110 self._test = None
#     111 self.perform_stat_test = None
#
# File ~/Apps/pyenv/lib/python3.11/site-packages/statannotations/Annotator.py:778, in Annotator._get_plotter(engine, *args, **kwargs)
#     776 if engine_plotter is None:
#     777     raise NotImplementedError(f"{engine} engine not implemented.")
# --> 778 return engine_plotter(*args, **kwargs)
#
# File ~/Apps/pyenv/lib/python3.11/site-packages/statannotations/_Plotter.py:87, in _SeabornPlotter.__init__(self, ax, pairs, plot, data, x, y, hue, order, hue_order, verbose, **plot_params)
#      85 self.check_plot_is_implemented(plot)
#      86 self.plot = plot
# ---> 87 self.plotter = self._get_plotter(plot, x, y, hue, data, order,
#      88                                  hue_order, **plot_params)
#      90 self.group_names, self.labels = self._get_group_names_and_labels()
#      91 self.groups_positions = _GroupsPositions(self.plotter,
#      92                                          self.group_names)
#
# File ~/Apps/pyenv/lib/python3.11/site-packages/statannotations/_Plotter.py:119, in _SeabornPlotter._get_plotter(self, plot, x, y, hue, data, order, hue_order, **plot_params)
#     116 self.fix_and_warn(dodge, hue, plot)
#     118 if plot == 'boxplot':
# --> 119     plotter = sns.categorical._BoxPlotter(
#     120
#     121         x, y, hue, data, order, hue_order,
#     122         orient=plot_params.get("orient"),
#     123         width=plot_params.get("width", 0.8),
#     124         dodge=True,
#     125         fliersize=plot_params.get("fliersize", 5),
#     126         linewidth=plot_params.get("linewidth"),
#     127         saturation=.75, color=None, palette=None)
#     129 elif plot == 'swarmplot':
#     130     plotter = sns.categorical._SwarmPlotter(
#     131         x, y, hue, data, order, hue_order,
#     132         orient=plot_params.get("orient"),
#     133         dodge=True, color=None, palette=None)
#
# AttributeError: module 'seaborn.categorical' has no attribute '_BoxPlotter'

# %%
factors_plotting=factors['Contexts'].copy()
factors_plotting['Condition']=pd.Series(context_dict)

# %%
factors_plotting=factors_plotting.melt(id_vars='Condition', 
                                      var_name='Factor')

# %%
factors_plotting=factors_plotting.query('Condition != "Undefined"')

# %%
(p9.ggplot(factors_plotting)+
    p9.geom_boxplot(p9.aes('Condition', 'value'))+
    p9.facet_wrap('~ Factor')+
    p9.theme_bw()
)

# %%
factors['Ligand-Receptor Pairs']
# Out:
#                Factor 1  Factor 2  Factor 3  Factor 4  Factor 5  Factor 6
# Adam10^Cd44    0.171661  0.262455  0.462152  0.046329  0.576593  0.626698
# Adam10^Notch2  0.171428  0.005415  0.397933  0.000141  0.534053  0.557241
# App^Notch2     0.636815  0.003489  0.065694  0.024273  0.038120  0.224694
# App^Rpsa       0.715306  0.039564  0.038696  0.758355  0.018857  0.074426
# Pkm^Cd44       0.129380  0.698628  0.535889  0.460527  0.435232  0.339068
# Vim^Cd44       0.084912  0.664401  0.578857  0.458341  0.437141  0.354595

# %%
tensor.get_top_factor_elements(order_name='Ligand-Receptor Pairs',
                                factor_name='Factor 6',
                                top_number=10)
# Out:
# Adam10^Cd44      0.626698
# Adam10^Notch2    0.557241
# Vim^Cd44         0.354595
# Pkm^Cd44         0.339068
# App^Notch2       0.224694
# App^Rpsa         0.074426
# Name: Factor 6, dtype: float64

# %%
lr_loadings = factors['Ligand-Receptor Pairs']
lr_loadings.sort_values("Factor 6", ascending=False).head(10)
# Out:
#                Factor 1  Factor 2  Factor 3  Factor 4  Factor 5  Factor 6
# Adam10^Cd44    0.171661  0.262455  0.462152  0.046329  0.576593  0.626698
# Adam10^Notch2  0.171428  0.005415  0.397933  0.000141  0.534053  0.557241
# Vim^Cd44       0.084912  0.664401  0.578857  0.458341  0.437141  0.354595
# Pkm^Cd44       0.129380  0.698628  0.535889  0.460527  0.435232  0.339068
# App^Notch2     0.636815  0.003489  0.065694  0.024273  0.038120  0.224694
# App^Rpsa       0.715306  0.039564  0.038696  0.758355  0.018857  0.074426

# %%
# load PROGENy pathways
net = dc.get_progeny(organism='mouse', top=5000)
# Out:
# Downloading annotations for all proteins from the following resources: `['PROGENy']`

# %%
# load full list of ligand-receptor pairs
lr_pairs = li.resource.select_resource('mouseconsensus')

# %%
# generate ligand-receptor geneset
lr_progeny = li.rs.generate_lr_geneset(lr_pairs, net, lr_sep="^")
lr_progeny.head()
# Out:
#       source  interaction    weight
# 15      EGFR  Dll1^Notch1 -1.000584
# 286     NFkB  Dll1^Notch2  0.809955
# 482     NFkB  Dll1^Notch4  0.677967
# 542    Trail  Dll1^Notch4  0.725850
# 633  Hypoxia  Dll1^Notch3  1.049842

# %%
lr_loadings
# Out:
#                Factor 1  Factor 2  Factor 3  Factor 4  Factor 5  Factor 6
# Adam10^Cd44    0.171661  0.262455  0.462152  0.046329  0.576593  0.626698
# Adam10^Notch2  0.171428  0.005415  0.397933  0.000141  0.534053  0.557241
# App^Notch2     0.636815  0.003489  0.065694  0.024273  0.038120  0.224694
# App^Rpsa       0.715306  0.039564  0.038696  0.758355  0.018857  0.074426
# Pkm^Cd44       0.129380  0.698628  0.535889  0.460527  0.435232  0.339068
# Vim^Cd44       0.084912  0.664401  0.578857  0.458341  0.437141  0.354595

# %%
lr_progeny['interaction']
# Out:
# 15        Dll1^Notch1
# 286       Dll1^Notch2
# 482       Dll1^Notch4
# 542       Dll1^Notch4
# 633       Dll1^Notch3
#              ...
# 385728     Kng1^Plaur
# 386270     Lyz1^Itgal
# 386466     Lyz2^Itgal
# 387461     Try4^F2rl2
# 387657     Try5^F2rl2
# Name: interaction, Length: 1169, dtype: object

# %%
# run enrichment analysis
estimate, pvals = dc.run_ulm(lr_loadings.transpose(), lr_progeny, source="source", target="interaction", use_raw=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 2
#       1 # run enrichment analysis
# ----> 2 estimate, pvals = dc.run_ulm(lr_loadings.transpose(), lr_progeny, source="source", target="interaction", use_raw=False)
#
# File ~/Apps/pyenv/lib/python3.11/site-packages/decoupler/method_ulm.py:109, in run_ulm(mat, net, source, target, weight, batch_size, min_n, verbose, use_raw)
#     107 # Transform net
#     108 net = rename_net(net, source=source, target=target, weight=weight)
# --> 109 net = filt_min_n(c, net, min_n=min_n)
#     110 sources, targets, net = get_net_mat(net)
#     112 # Match arrays
#
# File ~/Apps/pyenv/lib/python3.11/site-packages/decoupler/pre.py:149, in filt_min_n(c, net, min_n)
#     146 net = net[msk]
#     148 if net.shape[0] == 0:
# --> 149     raise ValueError("""No sources with more than min_n={0} targets. Make sure mat and net have shared target features or
#     150     reduce the number assigned to min_n""".format(min_n))
#     152 return net
#
# ValueError: No sources with more than min_n=5 targets. Make sure mat and net have shared target features or
#         reduce the number assigned to min_n

# %%
dc.plot_barplot(estimate, 'Factor 6', vertical=True, cmap='coolwarm', vmin=-7, vmax=7)
